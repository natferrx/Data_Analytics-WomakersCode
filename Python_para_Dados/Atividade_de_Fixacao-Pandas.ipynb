# %% [markdown]
# **Python para Dados - Atividade de Fixação Pandas**
#
# Utilizando o arquivo: carros.csv

# %%
import pandas as pd

# %% [markdown]
# **Dataframe e ordenação:**
#
# 1. Faça o upload do CSV carros.csv.
#
# 2. Printe seu head com 10 linhas.

# %%
df = pd.read_csv('carros.csv')

df.head(10)
# Out:
#          Região            Estado  Quant Carros  \
# 0           Sul              Acre          4342
# 1  Centro-Oeste           Alagoas         18991
# 2       Sudeste             Amapá          6463
# 3  Centro-Oeste          Amazonas          3180
# 4  Centro-Oeste             Bahia         11288
# 5      Nordeste             Ceará         10807
# 6       Sudeste  Distrito Federal          5786
# 7       Sudeste    Espírito Santo          5494
# 8       Sudeste             Goiás         24412
# 9  Centro-Oeste          Maranhão          8472
#
#    Quant Carros Família com Filhos  População do Estado  Carros por habitante
# 0                             1034              23942.0              0.181355
# 1                             3253              23431.0              0.810507
# 2                             4152               7747.0              0.834258
# 3                             2955               5189.0              0.612835
# 4                             2585              24118.0              0.468032
# 5                             4943              40773.0              0.265053
# 6                             4459               6899.0              0.838672
# 7                             4073               6267.0              0.876655
# 8                             2021              36551.0              0.667889
# 9                             4461              16394.0              0.516774

# %% [markdown]
# 3. Agora printe as colunas e index do dataframe.

# %%
df.columns
# Out:
# Index(['Região', 'Estado', 'Quant Carros', 'Quant Carros Família com Filhos',
#        'População do Estado', 'Carros por habitante'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %% [markdown]
# 4. Faça um sort decrescente no dataframe pelo estado com maior quantidade de carros.

# %%
df.sort_values('Quant Carros', ascending=False)
df_estado_carros = df[['Estado', "Quant Carros"]]
df_estado_carros
# Out:
#                  Estado  Quant Carros
# 0                  Acre          4342
# 1               Alagoas         18991
# 2                 Amapá          6463
# 3              Amazonas          3180
# 4                 Bahia         11288
# 5                 Ceará         10807
# 6      Distrito Federal          5786
# 7        Espírito Santo          5494
# 8                 Goiás         24412
# 9              Maranhão          8472
# 10          Mato Grosso          4868
# 11   Mato Grosso do Sul          5683
# 12         Minas Gerais         17291
# 13                 Pará         22387
# 14              Paraíba         10666
# 15               Paraná          6036
# 16           Pernambuco         10533
# 17                Piauí          7912
# 18       Rio de Janeiro         33848
# 19  Rio Grande do Norte          6396
# 20    Rio Grande do Sul          2241
# 21             Rondônia         23113
# 22              Roraima          3561
# 23       Santa Catarina          9466
# 24            São Paulo          6317
# 25              Sergipe         22307
# 26            Tocantins         17144

# %% [markdown]
# 5. Descubra qual a proporção de carro para a população de cada estado e insira em uma nova coluna.

# %%
proporcao = df['Quant Carros']/df['População do Estado']
df['Carros por habitante'] = proporcao
df.head()
# Out:
#          Região    Estado  Quant Carros  Quant Carros Família com Filhos  \
# 0           Sul      Acre          4342                             1034
# 1  Centro-Oeste   Alagoas         18991                             3253
# 2       Sudeste     Amapá          6463                             4152
# 3  Centro-Oeste  Amazonas          3180                             2955
# 4  Centro-Oeste     Bahia         11288                             2585
#
#    População do Estado  Carros por habitante
# 0              23942.0              0.181355
# 1              23431.0              0.810507
# 2               7747.0              0.834258
# 3               5189.0              0.612835
# 4              24118.0              0.468032

# %% [markdown]
# 6. Faça um dataframe com Estado e proporção de carro por habitante.

# %%
df_estado_hab = df[['Estado','Carros por habitante']]
df_estado_hab
# Out:
#                  Estado  Carros por habitante
# 0                  Acre              0.181355
# 1               Alagoas              0.810507
# 2                 Amapá              0.834258
# 3              Amazonas              0.612835
# 4                 Bahia              0.468032
# 5                 Ceará              0.265053
# 6      Distrito Federal              0.838672
# 7        Espírito Santo              0.876655
# 8                 Goiás              0.667889
# 9              Maranhão              0.516774
# 10          Mato Grosso              0.568957
# 11   Mato Grosso do Sul              0.639258
# 12         Minas Gerais              0.371004
# 13                 Pará              0.626385
# 14              Paraíba              0.546918
# 15               Paraná              0.225417
# 16           Pernambuco              0.674026
# 17                Piauí              0.573666
# 18       Rio de Janeiro              0.700453
# 19  Rio Grande do Norte              0.133192
# 20    Rio Grande do Sul              0.166828
# 21             Rondônia              0.481511
# 22              Roraima              0.222340
# 23       Santa Catarina              0.327577
# 24            São Paulo              0.829874
# 25              Sergipe              0.783169
# 26            Tocantins              0.773681

# %% [markdown]
# **Agregação de dados:**
#
# 7. Qual a média de idade por região?
#
# 8. Qual é a porcentagem de pessoas com deficiência?
#
# 9. Quantas pessoas são do estado do Piauí?
#
# Utilizando o arquivo: concurso.csv

# %% [markdown]
# **Indexação e fatiamento:**
#
# Temos como base inscrições em um concurso público, utilizando indexação retorne:
#
# 10. Quantas pessoas são do estado do Piauí?
#
# 11. Quantas do ES são do sexo feminino?
